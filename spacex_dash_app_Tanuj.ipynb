# %%
# !pip install dash
# !pip install dash==1.19.0
# !pip install jupyter_dash
# !pip install --upgrade plotly
# Out:
# Requirement already satisfied: dash in c:\users\tanuj pandey\anaconda3\lib\site-packages (1.19.0)
# Collecting dash-table==4.11.2
#   Downloading dash_table-4.11.2.tar.gz (1.8 MB)
# Requirement already satisfied: flask-compress in c:\users\tanuj pandey\anaconda3\lib\site-packages (from dash) (1.13)
# Collecting dash-html-components==1.1.2
#   Downloading dash_html_components-1.1.2.tar.gz (188 kB)
# Requirement already satisfied: Flask>=1.0.4 in c:\users\tanuj pandey\anaconda3\lib\site-packages (from dash) (1.1.2)
# Collecting dash-renderer==1.9.0
#   Downloading dash_renderer-1.9.0.tar.gz (1.0 MB)
# Requirement already satisfied: plotly in c:\users\tanuj pandey\anaconda3\lib\site-packages (from dash) (5.6.0)
# Requirement already satisfied: future in c:\users\tanuj pandey\anaconda3\lib\site-packages (from dash) (0.18.2)
# Collecting dash-core-components==1.15.0
#   Downloading dash_core_components-1.15.0.tar.gz (3.5 MB)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\tanuj pandey\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (2.11.3)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\tanuj pandey\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (2.0.1)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\tanuj pandey\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (2.0.3)
# Requirement already satisfied: click>=5.1 in c:\users\tanuj pandey\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (8.0.4)
# Requirement already satisfied: colorama in c:\users\tanuj pandey\anaconda3\lib\site-packages (from click>=5.1->Flask>=1.0.4->dash) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\tanuj pandey\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.0.4->dash) (2.0.1)
# Requirement already satisfied: brotli in c:\users\tanuj pandey\anaconda3\lib\site-packages (from flask-compress->dash) (1.0.9)
# Requirement already satisfied: six in c:\users\tanuj pandey\anaconda3\lib\site-packages (from plotly->dash) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\tanuj pandey\anaconda3\lib\site-packages (from plotly->dash) (8.0.1)
# Building wheels for collected packages: dash-core-components, dash-html-components, dash-renderer, dash-table
#   Building wheel for dash-core-components (setup.py): started
#   Building wheel for dash-core-components (setup.py): finished with status 'done'
#   Created wheel for dash-core-components: filename=dash_core_components-1.15.0-py3-none-any.whl size=3527003 sha256=ac9e0423079788dc79d56e1d8e2c7cb743db2d6380add215f8890d5b30bfd35f
#   Stored in directory: c:\users\tanuj pandey\appdata\local\pip\cache\wheels\17\6f\34\e5d7fe1c7189531b3c6c90266df517f73210b9ccf6aabd9c53
#   Building wheel for dash-html-components (setup.py): started
#   Building wheel for dash-html-components (setup.py): finished with status 'done'
#   Created wheel for dash-html-components: filename=dash_html_components-1.1.2-py3-none-any.whl size=427845 sha256=726f9fd354e9ec11ac186f3dc9f0e4703718d2620d099405330fa11571e72b2c
#   Stored in directory: c:\users\tanuj pandey\appdata\local\pip\cache\wheels\89\69\97\d277cdcfc9018c0c50a181a3572895c323f324ce30616e988e
#   Building wheel for dash-renderer (setup.py): started
#   Building wheel for dash-renderer (setup.py): finished with status 'done'
#   Created wheel for dash-renderer: filename=dash_renderer-1.9.0-py3-none-any.whl size=1014861 sha256=fb9b8fcbe82c0a09542ba9ac7e10a80d120002d9ee0c584c7dc3cab157cbaa19
#   Stored in directory: c:\users\tanuj pandey\appdata\local\pip\cache\wheels\9d\82\83\b39e9f2d6941ed7f500c579bb8c2e20c317638d84be58c63f2
#   Building wheel for dash-table (setup.py): started
#   Building wheel for dash-table (setup.py): finished with status 'done'
#   Created wheel for dash-table: filename=dash_table-4.11.2-py3-none-any.whl size=1839867 sha256=1399c3d19b594bc7730f962528e60f3863571fc66d878ce371214e27f5a4de9d
#   Stored in directory: c:\users\tanuj pandey\appdata\local\pip\cache\wheels\b6\7d\d0\1058eb26f3a2df4211086fb79bcb232357139aa1fc3abc15a2
# Successfully built dash-core-components dash-html-components dash-renderer dash-table
# Installing collected packages: dash-table, dash-renderer, dash-html-components, dash-core-components
#   Attempting uninstall: dash-table
#     Found existing installation: dash-table 4.4.1
#     Uninstalling dash-table-4.4.1:
#       Successfully uninstalled dash-table-4.4.1
#   Attempting uninstall: dash-renderer
#     Found existing installation: dash-renderer 1.1.2
#     Uninstalling dash-renderer-1.1.2:
#       Successfully uninstalled dash-renderer-1.1.2
#   Attempting uninstall: dash-html-components
#     Found existing installation: dash-html-components 1.0.1
#     Uninstalling dash-html-components-1.0.1:
#       Successfully uninstalled dash-html-components-1.0.1
#   Attempting uninstall: dash-core-components
#     Found existing installation: dash-core-components 1.3.1
#     Uninstalling dash-core-components-1.3.1:
#       Successfully uninstalled dash-core-components-1.3.1
# Successfully installed dash-core-components-1.15.0 dash-html-components-1.1.2 dash-renderer-1.9.0 dash-table-4.11.2
# Requirement already satisfied: dash==1.19.0 in c:\users\tanuj pandey\anaconda3\lib\site-packages (1.19.0)
# Requirement already satisfied: future in c:\users\tanuj pandey\anaconda3\lib\site-packages (from dash==1.19.0) (0.18.2)
# Requirement already satisfied: dash-renderer==1.9.0 in c:\users\tanuj pandey\anaconda3\lib\site-packages (from dash==1.19.0) (1.9.0)
# Requirement already satisfied: dash-core-components==1.15.0 in c:\users\tanuj pandey\anaconda3\lib\site-packages (from dash==1.19.0) (1.15.0)
# Requirement already satisfied: dash-html-components==1.1.2 in c:\users\tanuj pandey\anaconda3\lib\site-packages (from dash==1.19.0) (1.1.2)
# Requirement already satisfied: flask-compress in c:\users\tanuj pandey\anaconda3\lib\site-packages (from dash==1.19.0) (1.13)
# Requirement already satisfied: dash-table==4.11.2 in c:\users\tanuj pandey\anaconda3\lib\site-packages (from dash==1.19.0) (4.11.2)
# Requirement already satisfied: plotly in c:\users\tanuj pandey\anaconda3\lib\site-packages (from dash==1.19.0) (5.6.0)
# Requirement already satisfied: Flask>=1.0.4 in c:\users\tanuj pandey\anaconda3\lib\site-packages (from dash==1.19.0) (1.1.2)
# Requirement already satisfied: click>=5.1 in c:\users\tanuj pandey\anaconda3\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (8.0.4)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\tanuj pandey\anaconda3\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (2.11.3)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\tanuj pandey\anaconda3\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (2.0.1)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\tanuj pandey\anaconda3\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (2.0.3)
# Requirement already satisfied: colorama in c:\users\tanuj pandey\anaconda3\lib\site-packages (from click>=5.1->Flask>=1.0.4->dash==1.19.0) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\tanuj pandey\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.0.4->dash==1.19.0) (2.0.1)
# Requirement already satisfied: brotli in c:\users\tanuj pandey\anaconda3\lib\site-packages (from flask-compress->dash==1.19.0) (1.0.9)
# Requirement already satisfied: six in c:\users\tanuj pandey\anaconda3\lib\site-packages (from plotly->dash==1.19.0) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\tanuj pandey\anaconda3\lib\site-packages (from plotly->dash==1.19.0) (8.0.1)
# Collecting jupyter_dash
#   Downloading jupyter_dash-0.4.2-py3-none-any.whl (23 kB)
# Requirement already satisfied: ipykernel in c:\users\tanuj pandey\anaconda3\lib\site-packages (from jupyter_dash) (6.9.1)
# Collecting ansi2html
#   Downloading ansi2html-1.8.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: dash in c:\users\tanuj pandey\anaconda3\lib\site-packages (from jupyter_dash) (1.19.0)
# Requirement already satisfied: nest-asyncio in c:\users\tanuj pandey\anaconda3\lib\site-packages (from jupyter_dash) (1.5.5)
# Requirement already satisfied: ipython in c:\users\tanuj pandey\anaconda3\lib\site-packages (from jupyter_dash) (8.2.0)
# Requirement already satisfied: requests in c:\users\tanuj pandey\anaconda3\lib\site-packages (from jupyter_dash) (2.27.1)
# Collecting retrying
#   Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Requirement already satisfied: flask in c:\users\tanuj pandey\anaconda3\lib\site-packages (from jupyter_dash) (1.1.2)
# Requirement already satisfied: dash-renderer==1.9.0 in c:\users\tanuj pandey\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.9.0)
# Requirement already satisfied: plotly in c:\users\tanuj pandey\anaconda3\lib\site-packages (from dash->jupyter_dash) (5.6.0)
# Requirement already satisfied: dash-html-components==1.1.2 in c:\users\tanuj pandey\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.1.2)
# Requirement already satisfied: dash-table==4.11.2 in c:\users\tanuj pandey\anaconda3\lib\site-packages (from dash->jupyter_dash) (4.11.2)
# Requirement already satisfied: future in c:\users\tanuj pandey\anaconda3\lib\site-packages (from dash->jupyter_dash) (0.18.2)
# Requirement already satisfied: dash-core-components==1.15.0 in c:\users\tanuj pandey\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.15.0)
# Requirement already satisfied: flask-compress in c:\users\tanuj pandey\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.13)
# Requirement already satisfied: click>=5.1 in c:\users\tanuj pandey\anaconda3\lib\site-packages (from flask->jupyter_dash) (8.0.4)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\tanuj pandey\anaconda3\lib\site-packages (from flask->jupyter_dash) (2.11.3)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\tanuj pandey\anaconda3\lib\site-packages (from flask->jupyter_dash) (2.0.1)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\tanuj pandey\anaconda3\lib\site-packages (from flask->jupyter_dash) (2.0.3)
# Requirement already satisfied: colorama in c:\users\tanuj pandey\anaconda3\lib\site-packages (from click>=5.1->flask->jupyter_dash) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\tanuj pandey\anaconda3\lib\site-packages (from Jinja2>=2.10.1->flask->jupyter_dash) (2.0.1)
# Requirement already satisfied: brotli in c:\users\tanuj pandey\anaconda3\lib\site-packages (from flask-compress->dash->jupyter_dash) (1.0.9)
# Requirement already satisfied: traitlets<6.0,>=5.1.0 in c:\users\tanuj pandey\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (5.1.1)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\tanuj pandey\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (6.1.12)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\tanuj pandey\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (6.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\tanuj pandey\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (1.5.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\tanuj pandey\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (0.1.2)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\tanuj pandey\anaconda3\lib\site-packages (from ipython->jupyter_dash) (2.11.2)
# Requirement already satisfied: jedi>=0.16 in c:\users\tanuj pandey\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.18.1)
# Requirement already satisfied: pickleshare in c:\users\tanuj pandey\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.7.5)
# Requirement already satisfied: backcall in c:\users\tanuj pandey\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.2.0)
# Requirement already satisfied: decorator in c:\users\tanuj pandey\anaconda3\lib\site-packages (from ipython->jupyter_dash) (5.1.1)
# Requirement already satisfied: stack-data in c:\users\tanuj pandey\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\tanuj pandey\anaconda3\lib\site-packages (from ipython->jupyter_dash) (61.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\tanuj pandey\anaconda3\lib\site-packages (from ipython->jupyter_dash) (3.0.20)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\tanuj pandey\anaconda3\lib\site-packages (from jedi>=0.16->ipython->jupyter_dash) (0.8.3)
# Requirement already satisfied: pyzmq>=13 in c:\users\tanuj pandey\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter_dash) (22.3.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\tanuj pandey\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter_dash) (4.9.2)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\tanuj pandey\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter_dash) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\tanuj pandey\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel->jupyter_dash) (302)
# Requirement already satisfied: wcwidth in c:\users\tanuj pandey\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter_dash) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\tanuj pandey\anaconda3\lib\site-packages (from python-dateutil>=2.1->jupyter-client<8.0->ipykernel->jupyter_dash) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\tanuj pandey\anaconda3\lib\site-packages (from plotly->dash->jupyter_dash) (8.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tanuj pandey\anaconda3\lib\site-packages (from requests->jupyter_dash) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\tanuj pandey\anaconda3\lib\site-packages (from requests->jupyter_dash) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tanuj pandey\anaconda3\lib\site-packages (from requests->jupyter_dash) (2022.9.24)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\tanuj pandey\anaconda3\lib\site-packages (from requests->jupyter_dash) (2.0.4)
# Requirement already satisfied: executing in c:\users\tanuj pandey\anaconda3\lib\site-packages (from stack-data->ipython->jupyter_dash) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\tanuj pandey\anaconda3\lib\site-packages (from stack-data->ipython->jupyter_dash) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\tanuj pandey\anaconda3\lib\site-packages (from stack-data->ipython->jupyter_dash) (0.2.2)
# Installing collected packages: retrying, ansi2html, jupyter-dash
# Successfully installed ansi2html-1.8.0 jupyter-dash-0.4.2 retrying-1.3.4
# Requirement already satisfied: plotly in c:\users\tanuj pandey\anaconda3\lib\site-packages (5.6.0)
# Collecting plotly
#   Downloading plotly-5.11.0-py2.py3-none-any.whl (15.3 MB)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\tanuj pandey\anaconda3\lib\site-packages (from plotly) (8.0.1)
# Installing collected packages: plotly
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.6.0
#     Uninstalling plotly-5.6.0:
#       Successfully uninstalled plotly-5.6.0
# Successfully installed plotly-5.11.0

# %%
from jupyter_dash.comms import _send_jupyter_config_comm_request
_send_jupyter_config_comm_request()

# %%
import pandas as pd
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output
from jupyter_dash import JupyterDash
import plotly.graph_objects as go

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- --------------------
# aiofiles                      0.8.0
# aiohttp                       3.8.1
# aiosignal                     1.2.0
# alabaster                     0.7.12
# anaconda-client               1.9.0
# anaconda-navigator            2.1.4
# anaconda-project              0.10.2
# ansi2html                     1.8.0
# anyio                         3.5.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.2
# asgi-csrf                     0.9
# asgiref                       3.5.2
# astroid                       2.6.6
# astropy                       5.0.4
# asttokens                     2.0.5
# async-timeout                 4.0.1
# atomicwrites                  1.4.0
# attrs                         21.4.0
# Automat                       20.2.0
# autopep8                      1.6.0
# Babel                         2.9.1
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# backports.tempfile            1.0
# backports.weakref             1.0.post1
# bcrypt                        3.2.0
# beautifulsoup4                4.11.1
# binaryornot                   0.4.4
# bitarray                      2.4.1
# bkcharts                      0.2
# black                         19.10b0
# bleach                        4.1.0
# bokeh                         2.4.2
# boto3                         1.21.32
# botocore                      1.24.32
# Bottleneck                    1.3.4
# Brotli                        1.0.9
# brotlipy                      0.7.0
# bs4                           0.0.1
# cachetools                    4.2.2
# certifi                       2022.9.24
# cffi                          1.15.0
# chardet                       4.0.0
# charset-normalizer            2.0.4
# click                         8.0.4
# click-default-group-wheel     1.2.2
# cloudpickle                   2.0.0
# clyent                        1.2.2
# colorama                      0.4.4
# colorcet                      2.0.6
# comtypes                      1.1.10
# conda                         22.9.0
# conda-build                   3.22.0
# conda-content-trust           0+unknown
# conda-libmamba-solver         22.3.1
# conda-pack                    0.6.0
# conda-package-handling        1.8.1
# conda-repo-cli                1.0.4
# conda-token                   0.3.0
# conda-verify                  3.4.2
# constantly                    15.1.0
# cookiecutter                  1.7.3
# cryptography                  3.4.8
# cssselect                     1.1.0
# cycler                        0.11.0
# Cython                        0.29.28
# cytoolz                       0.11.0
# daal4py                       2021.5.0
# dash                          1.19.0
# dash-core-components          1.15.0
# dash-html-components          1.1.2
# dash-renderer                 1.9.0
# dash-table                    4.11.2
# dask                          2022.2.1
# datasette                     0.62
# datashader                    0.13.0
# datashape                     0.5.4
# debugpy                       1.5.1
# decorator                     5.1.1
# defusedxml                    0.7.1
# diff-match-patch              20200713
# distributed                   2022.2.1
# docutils                      0.17.1
# entrypoints                   0.4
# et-xmlfile                    1.1.0
# executing                     0.8.3
# fastjsonschema                2.15.1
# filelock                      3.6.0
# flake8                        3.9.2
# Flask                         1.1.2
# Flask-Compress                1.13
# fonttools                     4.25.0
# frozenlist                    1.2.0
# fsspec                        2022.2.0
# future                        0.18.2
# gensim                        4.1.2
# glob2                         0.7
# google-api-core               1.25.1
# google-auth                   1.33.0
# google-cloud-core             1.7.1
# google-cloud-storage          1.31.0
# google-crc32c                 1.1.2
# google-resumable-media        1.3.1
# googleapis-common-protos      1.53.0
# greenlet                      1.1.3.post0
# grpcio                        1.42.0
# h11                           0.12.0
# h5py                          3.6.0
# HeapDict                      1.0.1
# holoviews                     1.14.8
# html5lib                      1.1
# httpcore                      0.15.0
# httpx                         0.23.0
# hupper                        1.10.3
# hvplot                        0.7.3
# hyperlink                     21.0.0
# ibm-db                        3.1.0
# ibm-db-sa                     0.3.3
# idna                          3.3
# imagecodecs                   2021.8.26
# imageio                       2.9.0
# imagesize                     1.3.0
# importlib-metadata            4.11.3
# incremental                   21.3.0
# inflection                    0.5.1
# iniconfig                     1.1.1
# intake                        0.6.5
# intervaltree                  3.1.0
# ipykernel                     6.9.1
# ipympl                        0.8.7
# ipython                       8.2.0
# ipython-genutils              0.2.0
# ipython-sql                   0.4.1
# ipywidgets                    7.6.5
# isort                         5.9.3
# itemadapter                   0.3.0
# itemloaders                   1.0.4
# itsdangerous                  2.0.1
# janus                         1.0.0
# jdcal                         1.4.1
# jedi                          0.18.1
# Jinja2                        2.11.3
# jinja2-time                   0.2.0
# jmespath                      0.10.0
# joblib                        1.1.0
# json5                         0.9.6
# jsonschema                    4.4.0
# jupyter                       1.0.0
# jupyter-client                6.1.12
# jupyter-console               6.4.0
# jupyter-core                  4.9.2
# jupyter-dash                  0.4.2
# jupyter-dashboards-bundlers   0.9.1
# jupyter-server                1.13.5
# jupyterlab                    3.3.2
# jupyterlab-pygments           0.1.2
# jupyterlab-server             2.10.3
# jupyterlab-widgets            1.0.0
# keyring                       23.4.0
# kiwisolver                    1.3.2
# lazy-object-proxy             1.6.0
# libarchive-c                  2.9
# libmambapy                    0.22.1
# llvmlite                      0.38.0
# locket                        0.2.1
# lxml                          4.9.1
# Markdown                      3.3.4
# MarkupSafe                    2.0.1
# matplotlib                    3.5.1
# matplotlib-inline             0.1.2
# mccabe                        0.6.1
# menuinst                      1.4.18
# mergedeep                     1.3.4
# mistune                       0.8.4
# mkl-fft                       1.3.1
# mkl-random                    1.2.2
# mkl-service                   2.4.0
# mock                          4.0.3
# mplfinance                    0.12.9b1
# mpmath                        1.2.1
# msgpack                       1.0.2
# multidict                     5.1.0
# multipledispatch              0.6.0
# multitasking                  0.0.11
# munkres                       1.1.4
# mypy-extensions               0.4.3
# navigator-updater             0.2.1
# nbclassic                     0.3.5
# nbclient                      0.5.13
# nbconvert                     6.4.4
# nbformat                      5.3.0
# nest-asyncio                  1.5.5
# networkx                      2.7.1
# nltk                          3.7
# nose                          1.3.7
# notebook                      6.4.8
# numba                         0.55.1
# numexpr                       2.8.1
# numpy                         1.21.5
# numpydoc                      1.2
# olefile                       0.46
# openpyxl                      3.0.9
# packaging                     21.3
# pandas                        1.1.5
# pandas-datareader             0.10.0
# pandasql                      0.7.3
# pandocfilters                 1.5.0
# panel                         0.13.0
# param                         1.12.0
# paramiko                      2.8.1
# parsel                        1.6.0
# parso                         0.8.3
# partd                         1.2.0
# pathspec                      0.7.0
# patsy                         0.5.2
# pep8                          1.7.1
# pexpect                       4.8.0
# pickleshare                   0.7.5
# Pillow                        9.0.1
# Pint                          0.19.2
# pip                           21.2.4
# pkginfo                       1.8.2
# plotly                        5.11.0
# pluggy                        1.0.0
# poyo                          0.5.0
# prettytable                   0.7.2
# prometheus-client             0.13.1
# prompt-toolkit                3.0.20
# Protego                       0.1.16
# protobuf                      3.19.1
# psutil                        5.8.0
# ptyprocess                    0.7.0
# pure-eval                     0.2.2
# py                            1.11.0
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# pycodestyle                   2.7.0
# pycoingecko                   3.0.0
# pycosat                       0.6.3
# pycparser                     2.21
# pyct                          0.4.6
# pycurl                        7.44.1
# PyDispatcher                  2.0.5
# pydocstyle                    6.1.1
# pyerfa                        2.0.0
# pyflakes                      2.3.1
# Pygments                      2.11.2
# PyHamcrest                    2.0.2
# PyJWT                         2.1.0
# pylint                        2.9.6
# pyls-spyder                   0.4.0
# PyNaCl                        1.4.0
# pyodbc                        4.0.32
# pyOpenSSL                     21.0.0
# pyparsing                     3.0.4
# pyreadline                    2.1
# pyrsistent                    0.18.0
# PySocks                       1.7.1
# pytest                        7.1.1
# python-dateutil               2.8.2
# python-lsp-black              1.0.0
# python-lsp-jsonrpc            1.0.0
# python-lsp-server             1.2.4
# python-multipart              0.0.5
# python-slugify                5.0.2
# python-snappy                 0.6.0
# pytz                          2021.3
# pyviz-comms                   2.0.2
# PyWavelets                    1.3.0
# pywin32                       302
# pywin32-ctypes                0.2.0
# pywinpty                      2.0.2
# PyYAML                        6.0
# pyzmq                         22.3.0
# QDarkStyle                    3.0.2
# qstylizer                     0.1.10
# QtAwesome                     1.0.3
# qtconsole                     5.3.0
# QtPy                          2.0.1
# queuelib                      1.5.0
# randomuser                    1.6
# regex                         2022.3.15
# requests                      2.27.1
# requests-file                 1.5.1
# retrying                      1.3.4
# rfc3986                       1.5.0
# rope                          0.22.0
# rsa                           4.7.2
# Rtree                         0.9.7
# ruamel-yaml-conda             0.15.100
# s3transfer                    0.5.0
# scikit-image                  0.19.2
# scikit-learn                  1.1.3
# scikit-learn-intelex          2021.20220215.102710
# scipy                         1.7.3
# Scrapy                        2.6.1
# seaborn                       0.11.2
# Send2Trash                    1.8.0
# service-identity              18.1.0
# setuptools                    61.2.0
# sip                           4.19.13
# six                           1.16.0
# smart-open                    5.1.0
# sniffio                       1.2.0
# snowballstemmer               2.2.0
# sortedcollections             2.1.0
# sortedcontainers              2.4.0
# soupsieve                     2.3.1
# Sphinx                        4.4.0
# sphinxcontrib-applehelp       1.0.2
# sphinxcontrib-devhelp         1.0.2
# sphinxcontrib-htmlhelp        2.0.0
# sphinxcontrib-jsmath          1.0.1
# sphinxcontrib-qthelp          1.0.3
# sphinxcontrib-serializinghtml 1.1.5
# spyder                        5.1.5
# spyder-kernels                2.1.3
# SQLAlchemy                    1.3.9
# sqlparse                      0.4.3
# stack-data                    0.2.0
# statsmodels                   0.13.2
# sympy                         1.10.1
# tables                        3.6.1
# tabulate                      0.8.9
# TBB                           0.2
# tblib                         1.7.0
# tenacity                      8.0.1
# terminado                     0.13.1
# testpath                      0.5.0
# text-unidecode                1.3
# textdistance                  4.2.1
# threadpoolctl                 2.2.0
# three-merge                   0.1.1
# tifffile                      2021.7.2
# tinycss                       0.4
# tldextract                    3.2.0
# toml                          0.10.2
# tomli                         1.2.2
# toolz                         0.11.2
# tornado                       6.1
# tqdm                          4.64.0
# traitlets                     5.1.1
# Twisted                       22.2.0
# twisted-iocpsupport           1.0.2
# typed-ast                     1.4.3
# typing_extensions             4.1.1
# ujson                         5.1.0
# Unidecode                     1.2.0
# urllib3                       1.26.9
# uvicorn                       0.18.3
# w3lib                         1.21.0
# watchdog                      2.1.6
# wcwidth                       0.2.5
# webencodings                  0.5.1
# websocket-client              0.58.0
# Werkzeug                      2.0.3
# wheel                         0.37.1
# widgetsnbextension            3.5.2
# win-inet-pton                 1.1.0
# win-unicode-console           0.5
# wincertstore                  0.2
# wrapt                         1.12.1
# xarray                        0.20.1
# xlrd                          2.0.1
# XlsxWriter                    3.0.3
# xlwings                       0.24.9
# yapf                          0.31.0
# yarl                          1.6.3
# yfinance                      0.1.67
# zict                          2.0.0
# zipp                          3.7.0
# zope.interface                5.4.0

# %%
JupyterDash.infer_jupyter_proxy_config()

# %%
spacex_df = pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/lab_theia_plotly_dash.md.html')

# %%
# skeleton Dash app to be completed in this lab, downloaded from:
# https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/spacex_dash_app.py
# redundant lines commented out

# Import required libraries
# import pandas as pd
# import dash
# import dash_html_components as html
# import dash_core_components as dcc
# from dash.dependencies import Input, Output
import plotly.express as px

# Read the airline data into pandas dataframe
# spacex_df = pd.read_csv("spacex_launch_dash.csv")
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()

# Create a dash application
# app = dash.Dash(__name__) # commented out as we are using JupyterDash instead of dash.Dash
app = JupyterDash(__name__)

# Create an app layout
app.layout = html.Div(children=[html.H1('SpaceX Launch Records Dashboard',
                                        style={'textAlign': 'center', 'color': '#503D36',
                                               'font-size': 40}),
                                # TASK 1: Add a dropdown list to enable Launch Site selection
                                # The default select value is for ALL sites
                                # dcc.Dropdown(id='site-dropdown',...)
                                dcc.Dropdown(id='site-dropdown',
                                             options=[
                                                     {'label': 'All Sites', 'value': 'ALL'},
                                                     {'label': 'CCAFS LC-40', 'value': 'CCAFS LC-40'},
                                                     {'label': 'VAFB SLC-4E', 'value': 'VAFB SLC-4E'},
                                                     {'label': 'KSC LC-39A', 'value': 'KSC LC-39A'},
                                                     {'label': 'CCAFS SLC-40', 'value': 'CCAFS SLC-40'}
                                                     ],
                                             value='ALL',
                                             placeholder='Select a Launch Site here',
                                             searchable=True
                                             # style={'width':'80%','padding':'3px','font-size':'20px','text-align-last':'center'}
                                             ),
                                html.Br(),

                                # TASK 2: Add a pie chart to show the total successful launches count for all sites
                                # If a specific launch site was selected, show the Success vs. Failed counts for the site
                                html.Div(dcc.Graph(id='success-pie-chart')),
                                html.Br(),

                                html.P("Payload range (Kg):"),
                                # TASK 3: Add a slider to select payload range
                                #dcc.RangeSlider(id='payload-slider',...)
                                dcc.RangeSlider(id='payload-slider',
                                                min=0,
                                                max=10000,
                                                step=1000,
                                                value=[min_payload, max_payload]
                                                ),

                                # TASK 4: Add a scatter chart to show the correlation between payload and launch success
                                html.Div(dcc.Graph(id='success-payload-scatter-chart')),
                                ])

# %%
# TASK 2:
# Add a callback function for `site-dropdown` as input, `success-pie-chart` as output
@app.callback(Output(component_id='success-pie-chart', component_property='figure'),
              Input(component_id='site-dropdown', component_property='value'))
def get_pie_chart(entered_site):
    filtered_df = spacex_df
    if entered_site == 'ALL':
        fig = px.pie(filtered_df, values='class', 
        names='Launch Site', 
        title='Success Count for all launch sites')
        return fig
    else:
        # return the outcomes piechart for a selected site
        filtered_df=spacex_df[spacex_df['Launch Site']== entered_site]
        filtered_df=filtered_df.groupby(['Launch Site','class']).size().reset_index(name='class count')
        fig=px.pie(filtered_df,values='class count',names='class',title=f"Total Success Launches for site {entered_site}")
        return fig

# TASK 4:
# Add a callback function for `site-dropdown` and `payload-slider` as inputs, `success-payload-scatter-chart` as output
@app.callback(Output(component_id='success-payload-scatter-chart',component_property='figure'),
                [Input(component_id='site-dropdown',component_property='value'),
                Input(component_id='payload-slider',component_property='value')])
def scatter(entered_site,payload):
    filtered_df = spacex_df[spacex_df['Payload Mass (kg)'].between(payload[0],payload[1])]
    # thought reusing filtered_df may cause issues, but tried it out of curiosity and it seems to be working fine
    
    if entered_site=='ALL':
        fig=px.scatter(filtered_df,x='Payload Mass (kg)',y='class',color='Booster Version Category',title='Success count on Payload mass for all sites')
        return fig
    else:
        fig=px.scatter(filtered_df[filtered_df['Launch Site']==entered_site],x='Payload Mass (kg)',y='class',color='Booster Version Category',title=f"Success count on Payload mass for site {entered_site}")
        return fig

# Run the app
if __name__ == '__main__':
    app.run_server(mode='inline', host='localhost')
